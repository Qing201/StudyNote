# %%
import pandas as pd

# %%
df_akas = pd.read_csv('Data/IMDB/title.akas.tsv',sep='\t')
# Out:
# /var/folders/nl/jzl2sdyd5g7gv2bk8lfg29tr0000gn/T/ipykernel_2943/2369649234.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_akas = pd.read_csv('Data/IMDB/title.akas.tsv',sep='\t')

# %%
df_akas.head(60)
# Out:
#       titleId  ordering                                        title region  \
# 0   tt0000001         1                                   Карменсіта     UA
# 1   tt0000001         2                                   Carmencita     DE
# 2   tt0000001         3                    Carmencita - spanyol tánc     HU
# 3   tt0000001         4                                   Καρμενσίτα     GR
# 4   tt0000001         5                                   Карменсита     RU
# 5   tt0000001         6                                   Carmencita     US
# 6   tt0000001         7                                   Carmencita     \N
# 7   tt0000001         8                                      カルメンチータ     JP
# 8   tt0000002         1                       Le clown et ses chiens     \N
# 9   tt0000002         2                       Le clown et ses chiens     FR
# 10  tt0000002         3                            A bohóc és kutyái     HU
# 11  tt0000002         4                    Der Clown und seine Hunde     DE
# 12  tt0000002         5                        Clovnul si cainii sai     RO
# 13  tt0000002         6                           Клоун и его собаки     RU
# 14  tt0000002         7                       The Clown and His Dogs     US
# 15  tt0000002         8                                        道化師と犬     JP
# 16  tt0000003         1                             Sarmanul Pierrot     RO
# 17  tt0000003         2                              Szegény Pierrot     HU
# 18  tt0000003         3                                       哀れなピエロ     JP
# 19  tt0000003         4                                 Бідний П'єро     UA
# 20  tt0000003         5                                 Бедный Пьеро     RU
# 21  tt0000003         6                               Pauvre Pierrot     \N
# 22  tt0000003         7                                 Poor Pierrot     GB
# 23  tt0000003         8                               Pauvre Pierrot     FR
# 24  tt0000003         9                                Armer Pierrot     DE
# 25  tt0000004         1                                  Un bon bock     \N
# 26  tt0000004         2                                  Un bon bock     FR
# 27  tt0000004         3                          Ein gutes Glas Bier     DE
# 28  tt0000004         4                               Un ţap de bere     RO
# 29  tt0000004         5                           Полная кружка пива     RU
# 30  tt0000004         6                                       一杯のビール     JP
# 31  tt0000004         7                                  A Good Beer     \N
# 32  tt0000004         8                             Egy jó pohár sör     HU
# 33  tt0000005        10                             Blacksmith Scene     US
# 34  tt0000005        11                             Blacksmith Scene     \N
# 35  tt0000005        12                       The Blacksmith's Forge     GB
# 36  tt0000005         1                          Blacksmithing Scene     US
# 37  tt0000005         2                             Ковальська сцена     UA
# 38  tt0000005         3                                Сцена в кузне     RU
# 39  tt0000005         4                             Blacksmith Scene     CA
# 40  tt0000005         5                              Blacksmith Shop     GB
# 41  tt0000005         6                          Blacksmith Scene #1     US
# 42  tt0000005         7                                Blacksmithing     US
# 43  tt0000005         8                                 Schmiedszene     DE
# 44  tt0000005         9                              A patkolókovács     HU
# 45  tt0000006         1                    Китайский опиумный притон     RU
# 46  tt0000006         2                   Chinezes Fumadores de Ópio     PT
# 47  tt0000006         3                            Chinese Opium Den     US
# 48  tt0000006         4                           Kínai ópiumbarlang     HU
# 49  tt0000006         5                            Chinese Opium Den     \N
# 50  tt0000006         6                       Chinesische Opiumhöhle     DE
# 51  tt0000007         1  Corbett and Courtney Before the Kinetograph     US
# 52  tt0000007         2  Corbett and Courtney Before the Kinetograph     \N
# 53  tt0000007         3                A Corbett-Courtney bokszmeccs     HU
# 54  tt0000007         4                         キネトグラフの前のコーベットとコートニー     JP
# 55  tt0000007         5                   The Corbett-Courtney Fight     US
# 56  tt0000007         6               Jim Corbett vs. Peter Courtney     US
# 57  tt0000007         7         Edison Kinetoscopic Record of Boxers     \N
# 58  tt0000007         8        Корбетт и Кортни перед кинематографом     RU
# 59  tt0000007         9   Corbett und Courtney vor dem Kinetographen     DE
#
#    language        types                  attributes isOriginalTitle
# 0        \N  imdbDisplay                          \N               0
# 1        \N           \N               literal title               0
# 2        \N  imdbDisplay                          \N               0
# 3        \N  imdbDisplay                          \N               0
# 4        \N  imdbDisplay                          \N               0
# 5        \N  imdbDisplay                          \N               0
# 6        \N     original                          \N               1
# 7        ja  imdbDisplay                          \N               0
# 8        \N     original                          \N               1
# 9        \N  imdbDisplay                          \N               0
# 10       \N  imdbDisplay                          \N               0
# 11       \N           \N               literal title               0
# 12       \N  imdbDisplay                          \N               0
# 13       \N  imdbDisplay                          \N               0
# 14       \N           \N       literal English title               0
# 15       ja  imdbDisplay                          \N               0
# 16       \N  imdbDisplay                          \N               0
# 17       \N  imdbDisplay                          \N               0
# 18       ja  imdbDisplay                          \N               0
# 19       \N  imdbDisplay                          \N               0
# 20       \N  imdbDisplay                          \N               0
# 21       \N     original                          \N               1
# 22       \N  imdbDisplay                          \N               0
# 23       \N  imdbDisplay                          \N               0
# 24       \N           \N               literal title               0
# 25       \N     original                          \N               1
# 26       \N  imdbDisplay                          \N               0
# 27       \N           \N               literal title               0
# 28       \N  imdbDisplay                          \N               0
# 29       \N  imdbDisplay                          \N               0
# 30       ja  imdbDisplay                          \N               0
# 31       \N           \N                          \N               0
# 32       \N  imdbDisplay                          \N               0
# 33       \N  imdbDisplay                          \N               0
# 34       \N     original                          \N               1
# 35       \N           \N  informal alternative title               0
# 36       \N  alternative                          \N               0
# 37       \N  imdbDisplay                          \N               0
# 38       \N  imdbDisplay                          \N               0
# 39       en  imdbDisplay                          \N               0
# 40       \N           \N  informal alternative title               0
# 41       \N  alternative                          \N               0
# 42       \N           \N  informal alternative title               0
# 43       \N           \N               literal title               0
# 44       \N  imdbDisplay                          \N               0
# 45       \N  imdbDisplay                          \N               0
# 46       \N           \N           promotional title               0
# 47       \N  imdbDisplay                          \N               0
# 48       \N  imdbDisplay                          \N               0
# 49       \N     original                          \N               1
# 50       \N           \N               literal title               0
# 51       \N  imdbDisplay                          \N               0
# 52       \N     original                          \N               1
# 53       \N  imdbDisplay                          \N               0
# 54       ja  imdbDisplay                          \N               0
# 55       \N  alternative                          \N               0
# 56       \N  alternative                          \N               0
# 57       \N           \N                          \N               0
# 58       \N  imdbDisplay                          \N               0
# 59       \N           \N               literal title               0

# %%
df_basic = pd.read_csv('Data/IMDB/title_basics.tsv',sep='\t')
df_rating = pd.read_csv('Data/IMDB/title_ratings.tsv',sep='\t')
df_akas = pd.read_csv('Data/IMDB/title.akas.tsv',sep='\t')
# Out:
# /var/folders/nl/jzl2sdyd5g7gv2bk8lfg29tr0000gn/T/ipykernel_2943/4139969402.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_basic = pd.read_csv('Data/IMDB/title_basics.tsv',sep='\t')
# /var/folders/nl/jzl2sdyd5g7gv2bk8lfg29tr0000gn/T/ipykernel_2943/4139969402.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_akas = pd.read_csv('Data/IMDB/title.akas.tsv',sep='\t')

# %%
df_rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1901
# 1  tt0000002            5.9       254
# 2  tt0000003            6.5      1694
# 3  tt0000004            5.7       166
# 4  tt0000005            6.2      2511

# %%
df_basic.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df_basic.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')

# %%
set(df_basic['titleType'].tolist())
# Out:
# {'movie',
#  'short',
#  'tvEpisode',
#  'tvMiniSeries',
#  'tvMovie',
#  'tvPilot',
#  'tvSeries',
#  'tvShort',
#  'tvSpecial',
#  'video',
#  'videoGame'}

# %%
df_movie = df_basic.loc[df_basic['titleType'] == 'movie']

# %%
df_movie.head()
# Out:
#         tconst titleType                 primaryTitle  \
# 8    tt0000009     movie                   Miss Jerry
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
# 587  tt0000591     movie             The Prodigal Son
# 610  tt0000615     movie           Robbery Under Arms
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                     Miss Jerry       0      1894      \N             45
# 498                     Bohemios       0      1905      \N            100
# 570  The Story of the Kelly Gang       0      1906      \N             70
# 587            L'enfant prodigue       0      1907      \N             90
# 610           Robbery Under Arms       0      1907      \N             \N
#
#                          genres
# 8                       Romance
# 498                          \N
# 570  Action,Adventure,Biography
# 587                       Drama
# 610                       Drama

# %%
df_movie_pre = df_movie[['tconst', 'primaryTitle', 'startYear', 'genres']]
df_movie_pre.set_index('tconst', inplace=True)

# %%
df_rating.set_index('tconst', inplace=True)

# %%
df_allSet = pd.concat([df_movie_pre, df_rating.reindex(df_movie_pre.index)], axis=1)

# %%
df_allSet.head()
# Out:
#                           primaryTitle startYear                      genres  \
# tconst
# tt0000009                   Miss Jerry      1894                     Romance
# tt0000502                     Bohemios      1905                          \N
# tt0000574  The Story of the Kelly Gang      1906  Action,Adventure,Biography
# tt0000591             The Prodigal Son      1907                       Drama
# tt0000615           Robbery Under Arms      1907                       Drama
#
#            averageRating  numVotes
# tconst
# tt0000009            5.3     198.0
# tt0000502            4.5      14.0
# tt0000574            6.0     778.0
# tt0000591            4.7      19.0
# tt0000615            4.5      23.0

# %%
df_allSet.to_csv('movie.csv')
