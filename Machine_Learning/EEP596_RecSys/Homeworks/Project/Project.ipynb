# %%
import torch
import pandas as pd

# %%
df = pd.read_csv('Data/movie.csv')
title = df[['tconst', 'primaryTitle']]
df.set_index('tconst', inplace = True)

# %%
print(df.shape)
df.head()
# Out:
# (616994, 5)
#                           primaryTitle startYear                      genres  \
# tconst
# tt0000009                   Miss Jerry      1894                     Romance
# tt0000502                     Bohemios      1905                          \N
# tt0000574  The Story of the Kelly Gang      1906  Action,Adventure,Biography
# tt0000591             The Prodigal Son      1907                       Drama
# tt0000615           Robbery Under Arms      1907                       Drama
#
#            averageRating  numVotes
# tconst
# tt0000009            5.3     198.0
# tt0000502            4.5      14.0
# tt0000574            6.0     778.0
# tt0000591            4.7      19.0
# tt0000615            4.5      23.0

# %%
df.dropna()
# Out:
#                           primaryTitle startYear                      genres  \
# tconst
# tt0000009                   Miss Jerry      1894                     Romance
# tt0000502                     Bohemios      1905                          \N
# tt0000574  The Story of the Kelly Gang      1906  Action,Adventure,Biography
# tt0000591             The Prodigal Son      1907                       Drama
# tt0000615           Robbery Under Arms      1907                       Drama
# ...                                ...       ...                         ...
# tt9916270     Il talento del calabrone      2020                    Thriller
# tt9916362                        Coven      2020               Drama,History
# tt9916428          The Secret of China      2019       Adventure,History,War
# tt9916538          Kuambil Lagi Hatiku      2019                       Drama
# tt9916730                       6 Gunn      2017                          \N
#
#            averageRating  numVotes
# ...
