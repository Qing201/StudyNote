# %% [markdown]
# ## Flower Classification
# In this programming assignment, we will be looking at Flower Classification with a real dataset which has a 'label' for every flower image. The images are divided into five classes: chamomile, tulip, rose, sunflower, dandelion.
# For each class there are about 800 photos. Photos are not high resolution, about 320x240 pixels. Photos are not reduced to a single size, they have different proportions!

# %% [markdown]
# ## Import Modules

# %%
import cv2 # First install your OpenCV-Python if you haven't
import os, pickle
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import sklearn
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# ## Loading the image data

# %%
image_path = "/Users/qingchuanhou/Desktop/flower_train/daisy/99306615_739eb94b9e_m.jpg"
sample_image = cv2.imread(image_path) # Image will be B,G,R order.
sample_image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)
plt.imshow(sample_image) # plt.imshow() will assume R, G, B order
plt.show()
print("Image Size: {}\n".format(sample_image.shape),
      "Image Data Type: {}, {}\n".format(type(sample_image), sample_image.dtype),
      "Max-Min Pixel Value: {}, {}".format(sample_image.max(), 
                                           sample_image.min()))

# Basic processing method - resize, normalization
sample_image_resize = cv2.resize(sample_image, (224, 224))
sample_image_norm_resize = sample_image_resize / 255.0
print("After normalization, Max-Min Pixel Value: {}, {}".format(sample_image_norm_resize.max(), 
                                           sample_image_norm_resize.min()))
plt.imshow(sample_image_norm_resize)
plt.show()
plt.imshow(sample_image_resize)
plt.show()
# Out:
# Image Size: (240, 180, 3)
#  Image Data Type: <class 'numpy.ndarray'>, uint8
#  Max-Min Pixel Value: 255, 0
# After normalization, Max-Min Pixel Value: 1.0, 0.0

# %% [markdown]
# ## Feature Extraction
#
# For feature extraction, you can use from the most simple statistics of the image, e.g., statistic of colors, histogram of intensity/color values, to many advanced feature extractors/descriptors(shape, texture) in traditional image processing and computer vision, e.g, SIFT(scale-invariant feature transform), SURF(speeded up robust features), LESH(Local energy-based shape histogram), Gabor filters. These feature descriptors are built into Open-CV Python package, you can directly use them

# %% [markdown]
# ### SIFT feature

# %%
gray = cv2.cvtColor(sample_image_resize, cv2.COLOR_RGB2GRAY)
print(gray.shape)
sift = cv2.SIFT_create(20) #limit the number of keypoints you want to constrain

kp, des = sift.detectAndCompute(sample_image_resize,None)
print(type(kp[1]))
for i in range(len(kp)):
    print(kp[i].pt, des[i])
print("Number of keypoints: {}, Feature Dimension For each keypoints: {}".format(len(kp), des[0].shape))
# Out:
# (224, 224)
# <class 'cv2.KeyPoint'>
# (85.17337799072266, 110.26838684082031) [  7.   6.  17.   8.  91.  57.  33.  57.  72.  39.  24.   4.  39.  15.
#   11.  79.  11.  11.  28.  19.  36.  36.  21.  26.  28.  17.  11.  25.
#   45.   5.   0.   4.  16.   3.   4.  52. 128.  26.  14.  30. 128.  32.
#    8.  14.  77.  13.  12.  88.  31.   8.  10.  76. 128.  58.  19.  28.
#    5.  13.   3.  26.  64.  11.   8.   1.   6.  10.  13. 101. 128.   0.
#    0.   0.  91. 128.  97.  45.  56.   0.   0.   3.  18.  51. 112. 128.
#   39.   1.   1.   2.   5.   6.  17.  34.  37.   5.   5.   3.   0.   1.
#    4.  67. 128.   7.   1.   1.   7.  25.  22.  12.  39.   6.  19.  50.
#   10.  27.  29.   6.   4.  18.  40.  25.   1.   9.  32.  32.  15.  13.
#    2.   0.]
# (124.25902557373047, 195.2568359375) [ 13.   2.   0.   1.   1.   1.   2.  11.   3.   1.   1.   3.   4.  14.
#   35.  35.   1.   0.   0.   4.   8.  34.  62.  31.   3.   0.   0.   0.
#    0.   0.  92.  76.  36.   1.   0.   1.   7.  10.   4.  18. 122.   6.
#    1.   2.   6.  41.  72. 122.  36.  10.   1.  10.  32. 122. 122. 109.
#   39.  16.   8.   1.   0.   1. 122. 122.  64.   6.   1.  15.  22.   4.
#    0.   1. 122.  85.  18.  34.  14.   6.   3.  17.  52.  85.  30. 122.
#   74.  22.   5.  10.  56. 122.  81.  30.   0.   0.   3.  12.  31.   7.
#    1.  11.   3.   1.   3.   8.  68.  75.  29.  30.   3.   1.   1.   5.
#   10.  47.  30. 105.  16.   3.   4.   3.  13.  77.  53.  21.   0.   0.
#    2.   5.]
# (86.40702056884766, 25.889999389648438) [  2.  37.  12.   3.   7.   2.   1.   1.   2.  44.  54.  14.   8.  17.
#    6.   1.   4.   8.  26.  15.  44.  37.  17.   6.  17.   6.   2.   1.
#    6.  13.  48.  38.   5.   6.   4.  20.  30.   2.   2.   5.  10.  37.
#  120. 120.  85.  10.   3.   6. 120. 118.  82.  19.   5.   3.   9.  35.
#   40.   5.   3.   5.   2.   3.  41.  33.   4.   2.   2.  11.  37.  20.
#    4.   5.  13.   7.   8.  38. 110. 120.  63.  48. 120.  36.  62.  15.
#    3.  10.  33. 120.  33.  10. 120.  84.   1.   0.   0.   6.  19.   3.
#    1.  10.  17.   6.   4.  20.   1.   1.  13.  82.  69.  27.  12.   6.
#    7.   9. 120. 120.  28.   4.   6.  11.   1.   2. 120. 120.   2.   2.
#   12.   8.]
# (86.40702056884766, 25.889999389648438) [  1.  12.  27.   3.   1.  11.  53.   4.   2.   6.  28.  29.  24.  48.
#   32.   4.  25.  17.   7.   4.   6.  15.  27.  69.  14.   2.   0.   6.
#   12.  11.  11.  40.   3.  15.  42.  20.  24.   5.   1.   1.  10.  40.
#  122. 129.  89.  13.   2.   4. 129. 129.  64.  21.   5.   2.   2.  19.
#   27.  25.  12. 109.  12.   1.   1.   6.   6.   4.   3.   4.  38.  15.
#    3.   3.  14.   8.   8.  26. 129. 129.  69.  28. 129.  50.  34.  56.
#   11.  21.  48.  90.  20.  13.  60. 129.   8.   0.   0.   2.   6.   7.
#   10.  13.   7.   7.   6.   4.   9.   3.   0.   2.  34.  40.  36.  11.
#    4.   1.   7.  73. 120.  34.  18.   8.   2.   0.  12. 129.  71.  40.
#   18.  20.]
# (50.044681549072266, 98.54303741455078) [ 18.  11.  10.  29.  62.  75.  11.  16.  40.  37.   4.   4.  41.  76.
#   19.  37.   1.   1.   0.  15.  76. 122.  36.   0.   0.   2.   3.   5.
#   41.  39.  26.   0.  33.  38. 122. 122.  27.   6.   1.   2. 122. 122.
#   31.  19.  12.  42.   6.  19.  22.   5.  13.  42. 122. 122.  18.   6.
#    3.   1.   1.   6.  60.  46.  88.  31.  89.  24.  44.  17.   0.   0.
#    9.   7. 122. 117.  70.  41.   2.   1.   1.  12.  18.  21.  91. 122.
#   32.  12.  10.  11.  29.  55.  15.   9.   9.  10.  27.  30.  17.   7.
#    0.   0.   1.  21.  94.   9.  57.  64.  11.   4.   1.   9.  15.   9.
#    9.  23.  43.   9.   1.   1.  10.  11.   7.  32.  32.   5.   2.   0.
#    2.   4.]
# (109.942626953125, 56.99501037597656) [  3.   4.  60.  84.  38.  10.   5.   3.  16.  35. 123.  22.   1.   2.
#    4.   6.   3.  10. 126.  49.   3.   6.   3.   1.   1.  11. 126.  51.
#    2.   1.   0.   0.  29.  22. 126. 126.   5.   0.   0.   1. 126.  68.
#  113.  20.   1.   8.  21.  62.  18.   5.  33.  41.  41. 108.  43.  26.
#    2.   9.  21.  19.  22.  40.  12.   2.  75.  12.  18.  57.  19.   1.
#    5.  30. 126. 126.  65.  16.   1.   1.   3.  25.  18.  36. 126. 112.
#   25.  17.   4.   5.   5.   6.  25.  35.  23.   9.   1.   0.  30.   4.
#    1.   4.   3.   2.   5.  44.  30.  62.  50.   5.   3.   2.   1.   8.
#   51.  43.  61.  14.   0.   0.   0.   2.  20.  14.  16.  38.   6.   0.
#    0.   0.]
# (106.95369720458984, 127.77413940429688) [ 16.  14.  70.  12.   0.   0.   4.  68.  48.  17.  66.  25.   0.   0.
#    0.  50.  39.   8.  13.  33.  12.  14.  16.  68.  26.   7.   6.  19.
#    6.  22.  53.  14.  28.  20. 131.  60.   0.   0.   2.  10. 131.  61.
#   61.  25.   4.   0.   0.  56.  74.  21.  17. 131.  78.   0.   1.  48.
#  131.  42.  14.  43.  11.   1.   1.   4.  41.   4.  13.   8.   0.   1.
#   48.  47. 131.  73.  25.  28.   5.   1.  12.  59.  51.  24.  25. 131.
#   52.  12.  47.  43. 131.  28.   3.   9.   4.   3.  15.  43.   2.   0.
#    2.   8.   5.  24. 131.  43.  20.   6.   2.   1.   1.   7.  57. 107.
#    7.  13.   5.   2.   5.  14.  57.  55.  15.  33.  16.  10.   7.   2.
#   15.  24.]
# (106.95369720458984, 127.77413940429688) [  1.  15.  25.  19.  19.  12.  12.   2.   0.   0.  12.  74.  86.  16.
#    5.   1.   0.   0.  25. 130.  68.  27.   2.   1.  10.   0.   1.  29.
#   10.   3.   6.  47.   7.   6.  10.  83.  54.  19.  17.   3.  97.  13.
#   15.  53.  46.  67.  38.  36.  12.   0.   0.   3.  91. 130.  47.  28.
#   18.   0.   0.   3.  14.  27.  24. 130.   8.   3.   4.  16.  70. 130.
#   13.   3. 130.  24.   2.   6.  29.  87.  18.  32.  66.  10.   0.   5.
#  130. 130.  25.  32.   8.   0.   0.   6.  51.  34.  30. 119.  19.   9.
#    5.   4.  11.  63.   3.   6.  67.   6.   6.   7.  21.  86.  20.  29.
#   35.   6.  17.  16.  85.  21.   8.  18.   7.   1.   3.   2.  24.  18.
#   18.  51.]
# (175.3150634765625, 202.4241485595703) [ 28. 122.  24.   0.   0.   0.   0.   0.  67. 106.  11.   0.   0.   0.
#    0.   8.  48.  10.   4.   3.   0.   0.   7.  65.  10.   8.   2.   1.
#    0.   3.  19.  44.  44. 101.   6.   1.   0.   0.   0.   4. 122. 122.
#   17.   6.   0.   0.   0.  24. 102.  45.  46. 108.   3.   0.   0.  30.
#   69.  79.  24.  19.   1.   1.   1.   4.  37.   9.   0.   0.   0.   0.
#    2.  25. 122. 122.  74.  18.   0.   0.   0.   6.  49. 108. 122. 122.
#    1.   0.   0.   1.  76. 122.  86.  37.   0.   0.   1.   1.   5.   3.
#    3.   1.   0.   0.   1.  10.   4.  23.  38.   4.   0.   0.   3.  15.
#   16.  39.  43.   9.   0.   0.  29.  60.  28.  53.  28.   8.   0.   0.
#   24. 113.]
# (138.1730194091797, 50.3094596862793) [  5.  45.  53.   5.   0.   1.   2.   4.   2.  25. 128.  19.   1.   0.
#    0.   2.   2.  52.  49.   4.   3.   4.   3.   0.   1.   4.   1.  15.
#   42.   4.   1.   0.   0.  23. 110.  87.  22.   2.   0.   0.  16.  56.
#  135. 135.  11.   8.  10.   5. 135. 135. 100.   6.   2.   1.   3.  10.
#   33.  18.   1.  32.  73.   6.   0.   0.  12.   6.  29.  87.  91.  10.
#    4.   5.  48.  10.  19.  39.  27.  31. 108.  61. 135.  54.   6.   4.
#    2.   7.  38.  70.  47.  17.   3.  18.  30.  16.   2.   5.  54.  12.
#   49.  72.   6.   0.   2.  28.  98.  15.   6.  10.   6.   5.  12.  32.
#   74. 100.   5.   8.   5.   4.   6.   6.  34.  85.   6.   2.   1.   2.
#    2.   5.]
# (118.52021789550781, 135.44041442871094) [ 14.  23.   4.   4.   8.  13.  18.   4.   1.  26.  20.  19.   6.  30.
#   30.   2.   1.  32.  70.  24.  15.  18.   3.   0.   0.  27. 119.  26.
#   18.  22.   4.   0.  29.  38.  52.  26.   4.   1.   3.  10.  11.  23.
#  102. 119.  50.  12.   4.   1. 119.  80.  52.  31.  27.  49.   8.   9.
#   11.  15.  42.  29. 119. 110.   5.   2.   2.   9.  48.  47.  36.  19.
#    3.   3.  45.  22.  55. 104. 114.  13.   0.   4. 119.  65.  31.  52.
#   36.   4.   1.  21.  14.   5.  13. 119. 119.  11.   1.   1.   1.   1.
#   12.  87. 119.  18.   4.   4.  41.  22.  44.  94.  19.   0.   0.   4.
#   76.  69.  47.  25.   5.   2.   3.  16.   4.   2.  20.  49.  55.   6.
#   10.  13.]
# (56.556156158447266, 64.55934143066406) [  1.   0.   2.   9.   9. 121.  75.   3.  37.   1.   1.   1.   1.  41.
#   90. 121.  15.   0.   0.   0.  19.  68.  25.  44.   0.   0.   0.   0.
#    5.  82.  57.   1.  26.  16.  27.  67.  49.  53.  17.   8. 121.  31.
#   11.   7.   7.  48.  88. 121.  13.   3.   2.  15.  86. 121.  54.  25.
#    1.   1.   1.   2.  12.  27.  43.   9.  16.   3.   1.   5.  23. 121.
#  111.  20. 121.  47.  26.  32.  13.  24.  55.  61.  17.  21.  36. 121.
#  121.  46.   5.   4.   8.  32.  22.  34.  20.  11.   7.   8.   0.   0.
#    0.   0.  16.  60.  53.   1.   3.   3.   4.  31.  69.  36.  16.   5.
#    1.   2.   4.  52.  71.  28.  17.   6.   7.   7.   3.   5.   7.  17.
#   42.  30.]
# (80.5663070678711, 128.37339782714844) [ 38.   6.   2.  18. 138.  12.   0.   0. 138.  23.   0.   1.  26.  18.
#    5.  17.  35.   3.   0.   1. 102.  80.  10.  33.  29.   5.   2.  19.
#   77.  29.  12.  34.  40.   6.  10.  17. 116.  13.   0.   1. 138.  26.
#    5.  13.  36.  17.   6.  52.  55.  18.   9.  72. 138.  64.   8.  24.
#   19.  20.   8.  49. 106.   4.   0.   2.  21.  18.   7.  12.  71.  16.
#    4.   4. 138. 138.  69.  55.  30.   9.   0.   5.  21.  52.  77. 138.
#   60.   1.   0.   3.   8.  35.  30.  48.  50.   2.   0.   3.  10.   2.
#    1.  20.  36.  42.  16.  11.   4.  30.  32.  29.  44.  25.   2.   4.
#   17.  19.  29.  27.   1.   0.  10.  13.  12.  10.   4.  14.  28.   5.
#    4.   6.]
# (97.12227630615234, 137.33694458007812) [  2.  13.  85.  79.  10.   0.   0.   0.  76.  56.  85.  50.  11.   0.
#    1.  25.  98.  26.   7.   5.  15.  20.   7.  29.   6.   5.   6.  16.
#  126. 102.   4.   3.  16.  16.  42.  71.  19.   7.   2.   2. 133.  13.
#    6.  34.  11.   3.   6. 100.  86.   9.  22.  68.  56.  17.  17.  62.
#    6.   4.  41. 109.  80.  36.   1.   2.  20.   2.   2.  11.  67.  42.
#    4.   2. 133.  89.   4.   9.  13.   6.   1.  11.  66.  40.  11.  83.
#  133.  16.   2.   4.   7.   3.  17.  41.  52.  16.   5.  11.   5.   2.
#    6.  35.  44.  10.   1.   1. 114. 105.   8.   2.  10.   6.   2.   1.
#   25.  83.  49.  26.  41.   6.   0.   0.   0.   5.  11.  14.  45.  29.
#    0.   0.]
# (107.91252899169922, 220.56971740722656) [  0.   0.   0.   0.   1.   0.   0.   0.  28.   2.   0.   0.   1.   0.
#    0.   2.  18.   4.  11.   7.   0.   0.   0.   1.   0.   1.  22.  55.
#    3.   0.   0.   0.  13.  18.  20.  83.  34.   0.   0.   1. 133.  55.
#   11.  33.  21.   1.   0.  39.  90.  26.  88. 133.  15.   0.   0.   9.
#    0.   0. 133. 133.   6.   0.   0.   0.   8.  44.  92. 121.   4.   0.
#    0.   0.  91. 133.  75.  31.   2.   0.   0.   3.  13. 114. 116. 133.
#   65.   4.   0.   1.   0.   1.  35. 104.  83.  25.   0.   0.   3.   8.
#   16.   8.   7.   5.   1.   3.   6.  86.  16.   1.   2.   1.   0.   0.
#    2. 113.  72.   9.   7.   1.   0.   0.   1.  14.  32.  14.  28.  16.
#    0.   0.]
# (121.96416473388672, 137.6692657470703) [  5.   2.  11.  41.  39.  57.   5.   3.  26.   7.   2.   6.  24.  39.
#   34.  36.  20.   1.   0.   0.  42.  93.  28.  48. 118.  25.   3.   2.
#    1.   2.   6.  74.  35.  13.  34. 118.  17.   1.   4.   7. 118.  25.
#    6.   6.  15.  33.  27.  77.  56.   6.   1.   0.  93. 118.  43.  64.
#   80.   8.   0.   0.   3.   9.  23. 118.  30.   2.   0.  18.   8.   2.
#   43.  58. 118. 107.   6.   0.   8.   6.  54.  49.  43.  59.  12.   2.
#   47.  77.  51.  62.  30.   8.  15.   1.   2.  12.  33. 103.  16.   0.
#    0.   0.   0.   3.  67. 103.  36.  17.   6.   0.   0.   0. 105. 107.
#   16.  27.  17.   0.   0.   3.  69.  70.   3.  10.  11.   1.   1.  21.
#   52.   5.]
# (121.96416473388672, 137.6692657470703) [  7.  19.  20.  17.   6.  20.  13.   1.   1.  44.  64.  26.  10.  14.
#    3.   0.   0.  18. 117.  35.  20.  31.   5.   0.   4.  21.  79.  50.
#   10.   6.   2.   1.  10.  15.  83. 114.  25.   2.   1.   1. 117.  63.
#   66.  63.  38.  21.   2.  11.  19.  21.  84.  76. 117.  52.   2.   4.
#    0.  29. 117.  69.  14.   0.   0.   0.  22.  17.  71. 117.  46.   1.
#    0.   1. 117.  97.  51.  73.  25.   1.   0.  10.  13.  11.  27. 117.
#  117.   9.  12.   4.   1.   7.  32.  29.  17.   3.  32.  53.  45.  15.
#   15.  61.  49.   1.   0.   3.  74.  50.  37.  18.   8.   0.   0.   9.
#   27.  11.  15.  31.  32.   8.  40.  39.  13.   1.   0.   0.   2.   3.
#   94.  81.]
# (78.83916473388672, 107.40150451660156) [ 13.   2.   8.  18.   7.  38.  43.  14. 128.   4.   1.   2.   2.  12.
#   10.  61.  18.   0.   0.   4.  16.  20.  25.  26.   4.   0.   1.  24.
#   31.   5.   2.  14.  38.   9.   4.  17.  97.  61.  46.  44. 128.  10.
#    3.  12.  48.  22.  10.  53.  39.   5.   9. 126.  63.  23.  23.  27.
#   63.   7.   6.  52.  35.   4.   3.  36.  24.  24.  20.  65.  73.  13.
#    9.   4. 128.  67.  26.  64.  40.   8.  11.   9.  39.  20.  36. 128.
#   23.   8.  28.  23. 128.   6.   8.  27.   2.   4.  10. 108.   2.   1.
#    3.   6.   8.  55. 109.  16.  14.  10.   4.   8.   5.  39. 128.  36.
#    7.   2.   3.  13.   7.  18. 128.  38. 105.   3.   1.   2.   2.   4.
#   35.  77.]
# (78.83916473388672, 107.40150451660156) [  7.   1.   8.  97.  19.   1.   4.  26.   6.   9.  55. 126.  30.  18.
#   12.   3.  58.  66.  25.  23.   3.  17.  21.  16.  11.  19.   3.   6.
#   32.  77.  28.  10.  17.   7.  16. 126.  57.  20.   0.   1. 126.  18.
#   11.  44.  14.  71.  53.  41.  34.  96.  12.   1.  15. 126.  37.  10.
#    8.  79.  82.  61.  41.  37.   3.   2.  22.   2.   3.  16. 115. 126.
#    6.   7. 126.  51.   8.   8.  14.  43.  11.  24.  25.  21.  17.  27.
#   65. 126.   5.   3.   3.   4.  22.  14.  48. 126.   4.   1.   2.   5.
#   29.  14.  61.  65.   2.   1.  48.  49.   7.   3.  26.  46.   5.   4.
#   11.  34.  23.  22.  12.   5.   0.   0.   1.   0.   2.   9.  34.  62.
#    9.   1.]
# (61.20175552368164, 99.73603057861328) [ 19.  33.  12.   8.  14.   7.  21.  31.  79.  91.  32.   6.   0.   0.
#   18.  79.  80. 106.   9.   9.  32.  56.  10.  49.  27.  13.   6.  17.
#   63. 113.   8.   6.  35.  28.  10.  16.  97.  11.   2.   3. 123.  54.
#   15.   5.   3.   2.  16. 123.  53.  35.  16.  58.  49.  17.  37.  92.
#    1.   3.   9.  66.  59.  18.   1.   0.  31.   2.   1.  16.  60.  15.
#   93.  39. 123.  90.  23.  13.   3.   4.  88.  76.  28.  32.  73. 120.
#   27.  16.   9.  12.   1.   3.  24.  37.  20.   4.   5.   3.  48.  24.
#    8.   2.   1.   3.  64.  56.  25.  19.  56.  79.   7.   7. 102.  49.
#    5.  31.  59.  57.  12.  18.  12.   8.   6.  15.   3.   3.  14.  12.
#    8.   4.]
# Number of keypoints: 20, Feature Dimension For each keypoints: (128,)

# %%
gray = cv2.cvtColor(sample_image_resize, cv2.COLOR_RGB2GRAY)
print(gray.shape)
print(sample_image_resize.shape)
sift = cv2.SIFT_create(20) #limit the number of keypoints you want to constrain

kp, des = sift.detectAndCompute(sample_image_resize,None)
print(des[0])
kp, des = sift.detectAndCompute(gray,None)
print(des[0])
# Out:
# (224, 224)
# (224, 224, 3)
# [  7.   6.  17.   8.  91.  57.  33.  57.  72.  39.  24.   4.  39.  15.
#   11.  79.  11.  11.  28.  19.  36.  36.  21.  26.  28.  17.  11.  25.
#   45.   5.   0.   4.  16.   3.   4.  52. 128.  26.  14.  30. 128.  32.
#    8.  14.  77.  13.  12.  88.  31.   8.  10.  76. 128.  58.  19.  28.
#    5.  13.   3.  26.  64.  11.   8.   1.   6.  10.  13. 101. 128.   0.
#    0.   0.  91. 128.  97.  45.  56.   0.   0.   3.  18.  51. 112. 128.
#   39.   1.   1.   2.   5.   6.  17.  34.  37.   5.   5.   3.   0.   1.
#    4.  67. 128.   7.   1.   1.   7.  25.  22.  12.  39.   6.  19.  50.
#   10.  27.  29.   6.   4.  18.  40.  25.   1.   9.  32.  32.  15.  13.
#    2.   0.]
# [ 37.   4.   2.  25. 129.  10.   0.   0. 140.  14.   0.   1.  28.  14.
#    3.  13.  38.   2.   0.   0. 133.  64.   6.  27.  29.   5.   3.  21.
#   74.  24.  10.  33.  38.   7.   8.  14. 108.  17.   0.   1. 140.  27.
#    5.  14.  38.  15.   4.  39.  57.  18.   9.  78. 140.  48.   5.  19.
#   18.  19.   8.  53.  98.   2.   0.   2.  21.  15.   3.  12.  80.  14.
#    2.   4. 140. 140.  70.  56.  34.   7.   0.   3.  20.  52.  77. 140.
#   52.   0.   0.   3.   7.  34.  29.  48.  47.   1.   0.   3.   9.   2.
#    1.  25.  42.  37.   8.   7.   4.  26.  32.  30.  43.  18.   2.   4.
#   19.  17.  27.  25.   0.   1.  10.  13.  11.   9.   5.  15.  28.   5.
#    4.   6.]

# %% [markdown]
# ### Color Histogram feature

# %%
H = cv2.cvtColor(sample_image_resize, cv2.COLOR_BGR2HSV)[...,0]
print(H.shape)
hue_dist, bins = np.histogram(H, bins=250)
plt.hist(H.reshape((-1,)))
plt.show()
plt.hist(hue_dist,bins)
plt.show()
# Out:
# (224, 224)

# %% [markdown]
# ### Process the features into what you can fit into ML models
# Especially for feature like SIFT, you want to reduce dimensionality since (num_keypoints, 128) is very large. First you might want to limit the number of keypoints to extract. Also, you want to reduce the dims by a method called `bag of visual words`, where you treat each 128-d vector as a visual word, and assign it a label. However, the vector space is continuous unlike the vocabularies where the representation is discrete. So in this case, what you want to do is to
# discretize the 128-d space by some clustering method, e.g, KMeans, (you need to choose num_clusters yourself). After you perform clustering using all your training data of size(num_images x num_keypoints, 128), each of these vector will have a cluster label ranging from 0 - num_clusters - 1, then you can treat them as so-called 'visual word'. For each image, now your representation becomes a bag of visual words, quite similar to the representation of the document.

# %%
## Steps to turn SIFT features into trainable features
train_path = "/Users/qingchuanhou/Desktop/flower_train/"
test_path = "/Users/qingchuanhou/Desktop/flower_test/"


## Read Image
def Img_path(path):
    df = pd.DataFrame(columns=['img_path', 'label'])
    for label in os.listdir(path):
        
        if not label.startswith('.'):
            label_path = os.path.join(path, label)

            for image_name in os.listdir(label_path):
                image_path = os.path.join(label_path, image_name)
                
                df = df.append({'img_path': image_path, 'label': label}, ignore_index = True)
    
    return df


train_valid_df = Img_path(train_path)
test_df = Img_path(test_path)

# %%
samples_test = train_valid_df.sample(n=100)
print(samples_test.shape)
samples_test.head()
# Out:
# (100, 2)
#                                                img_path      label
# 954   /Users/qingchuanhou/Desktop/flower_train/rose/...       rose
# 2216  /Users/qingchuanhou/Desktop/flower_train/dande...  dandelion
# 2423  /Users/qingchuanhou/Desktop/flower_train/dande...  dandelion
# 2078  /Users/qingchuanhou/Desktop/flower_train/dande...  dandelion
# 64    /Users/qingchuanhou/Desktop/flower_train/daisy...      daisy

# %%
def Img_read(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    image_resize = cv2.resize(image, (224, 224))

    # image_norm_resize = image_resize /225.0

    gray = cv2.cvtColor(image_resize, cv2.COLOR_RGB2GRAY)

    return (gray)


def SIFT(img, n=20):
    sift = cv2.SIFT_create(n)
    kp, des = sift.detectAndCompute(img,None)
    return des


def List_SIFT(df, K=100, sift_n=20):
    img_path = list(df)
    feature_number = []
    sift_data = []
    for i in range(len(df)):
        img = Img_read(img_path[i])
        sift_img = SIFT(img,sift_n)
        feature_number.append(len(sift_img))
        sift_data.append(sift_img)
        
    sift_data = np.vstack(sift_data)
    return sift_data, feature_number

# %%
## Bag of visual words representation
def kmeans_gen(df_img_path, K=100, sift_n=20):

    # SIFT
    sift_data, feature_number = List_SIFT(df_img_path, sift_n)

    kmeans = KMeans(n_clusters=K, random_state=0).fit(sift_data)

    ## Assign Label to train data

    klabel = kmeans.labels_

    sample_number = len(df_img_path)
    klabel_img = np.zeros((sample_number, K))

    index = 0
    for i in range(sample_number):
        for j in range(feature_number[i]):
            label = klabel[index]
            index += 1
            klabel_img[i][label] += 1

    
    return kmeans, klabel_img      

K = 20
n = 50

kmeans, klabel_tv = kmeans_gen(train_valid_df['img_path'], K, n)

# %%
def kmeans_pred(df, sift_n=20):

    # SIFT
    sift_data, feature_number = List_SIFT(df, sift_n)

    ## Assign Label to test data

    klabel = kmeans.predict(sift_data)

    sample_number = len(df)
    klabel_img = np.zeros((sample_number, K))

    index = 0
    for i in range(sample_number):
        for j in range(feature_number[i]):
            label = klabel[index]
            index += 1
            klabel_img[i][label] += 1
    return klabel_img

klabel_test = kmeans_pred(test_df['img_path'])

# %% [markdown]
# ## Fit into your ML models
# Try a variable list of classical ML models you've learned so far in class to perform this multi-classification, i.e.,
# RandomForest, Multinomial Logistic Regression(LR for multi-class scenario), and also some others classical approach
# like SVM(kernel), NaiveBayes etc. Compare the models you've tried on the classification accuracy on test data, plot the confusion matrix. You can experiment on a large vareity of image features not limited to SIFT introduced here, but SIFT can be a decent baseline for you to work on. In this assignment, we do not expect you to be able to achieve high accuracy on the test result since image classification using traditional feature extraction is quited limited. When we later introduce Deep Neural Nets and especially CNN(Convolutional Neural Network), you will easily achieve a high performance. The purpose of this assignment is let you understand and explore how you can do feature engineering in image domain and let you learn some fundamentals of digital image processing.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
X_train, X_valid, y_train, y_valid = train_test_split(klabel_tv, train_valid_df["label"], test_size=0.1, random_state=0)

# %%
X_test = klabel_test
y_test = test_df["label"]

# %%
# RandomForest
RF_clf = RandomForestClassifier(max_depth=5, random_state=0)
RF_clf.fit(X_train, y_train)

RF_pred_valid = RF_clf.predict(X_valid)

cm = confusion_matrix(y_valid, RF_pred_valid, )#, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

print('RandomForest accuracy_score',RF_clf.score(X_valid, y_valid))
# Out:
# RandomForest accuracy_score 0.37283236994219654

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
# SVM
SVM_clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
SVM_clf.fit(X_train, y_train)

SVM_pred_valid = SVM_clf.predict(X_valid)

cm = confusion_matrix(y_valid, SVM_pred_valid)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

print('RandomForest accuracy_score',SVM_clf.score(X_valid, y_valid))
# Out:
# RandomForest accuracy_score 0.4161849710982659

# %% [markdown]
# # Test data

# %%
SVM_clf.fit(X_train, y_train)

SVM_pred_test = SVM_clf.predict(X_test)

cm = confusion_matrix(y_test, SVM_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

print('RandomForest accuracy_score',SVM_clf.score(X_test, y_test))
# Out:
# RandomForest accuracy_score 0.3919075144508671

# %%
# RandomForest
RF_clf = RandomForestClassifier(max_depth=5, random_state=0)
RF_clf.fit(X_train, y_train)

RF_pred_test = RF_clf.predict(X_test)

cm = confusion_matrix(y_test, RF_pred_test)#, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

print('RandomForest accuracy_score',RF_clf.score(X_test, y_test))
# Out:
# RandomForest accuracy_score 0.38497109826589593
