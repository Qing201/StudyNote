# %%
import PyPDF2
import sys

class PdfDirGenerator:

    def __init__(self, pdf_path:str, txt_path:str, offset:int, out_path:str=None, levelmark:str='.'):
        
        self.pdf_path = pdf_path    # pdf路径
        self.txt_path = txt_path    # 包含pdf目录信息的txt
        self.offset = offset        # 目录页数偏移量
        self.out_path = out_path    # 输出路径
        self.levelmark = levelmark  # 用于判断书签级别的标志符
    
          
        self.dir_parent = [None]    

    def getLevelId(self, level):
        """计算书签的级数（级数的标志符号为“.”）
        一级目录: 0 个“.”，例如: 第1章、附录A等
            二级目录: 1个“.”，例如: 1.1、A.1
                三级目录: 2个“.”，例如: 2.1.3
        """
        mark_num = 0
        for c in level:
            if c == self.levelmark:
                mark_num += 1
        return mark_num + 1

    def run(self):
        
        print("--------------------------- Adding the bookmark ---------------------------")
        print(" * PDF Source: %s" % self.pdf_path)
        print(" * TXT Source: %s" % self.txt_path)
        print(" * Offset: %d" % self.offset)
        print("---------------------------------------------------------------------------")
        with open(self.txt_path, 'r', encoding='utf-8') as txt:
            
            pdf_reader = PyPDF2.PdfReader(self.pdf_path)
            pdf_writer = PyPDF2.PdfWriter()
            
            pdf_writer.clone_document_from_reader(pdf_reader)
            # BUG: ValueError: {’/Type’: ‘/Outlines’, ‘/Count’: 0} is not in list
            # 修改代码 ${PYTHON_PATH}/site-packages/PyPDF2/pdf.py): getOutlineRoot 函数
            # 参考：https://www.codetd.com/en/article/11823498

            lines = txt.readlines()
            num_all_lines = len(lines)
            for i, line in enumerate(lines):

                # if i == 32:
                #     self.offset += 122
                # if i == 93:
                #     self.offset += 100
                # if i == 119:
                #     self.offset += 110
                

                # pline = line.split(' ') # 要求level title page之间只能有一个空格且不能是\t, 比较麻烦换成下面这个
                pline = line.split(None, maxsplit=-1) # python 3.6.13, 支持删除\t\n 空格, 且不限次数
                if len(pline) == 2:
                    level = pline[0]; title = ""; page = int(pline[1]) + self.offset
                elif len(pline) == 3:
                    level = pline[0]; title = pline[1]; page = int(pline[2]) + self.offset
                else:       # 英文中包含空格
                    level = pline[0]; title = ' '.join(pline[1:len(pline)-1]); page = int(pline[len(pline)-1]) + self.offset

                # 1. 计算当前的 level 的级数 id
                # 2. 当前书签的父结点存放在 dir_parent[id-1] 上
                # 3. 更新/插入 dir_parent[id] 
                id = self.getLevelId(level)
                if id >= len(self.dir_parent):
                    self.dir_parent.append(None)
                self.dir_parent[id] = pdf_writer.add_outline_item(level+' '+title, page-1, self.dir_parent[id-1])
                
                print(" * [%d/%d finished] level: %s(%d), title: %s, page: %d" % (i+1, num_all_lines, level, id, title, page))
            
            if self.out_path is None:
                self.out_path = self.pdf_path[:-4] + '(书签).pdf'
            with open(self.out_path, 'wb') as out_pdf:
                pdf_writer.write(out_pdf)
                print("---------------------------------------------------------------------------")
                print(" * Save: %s" % self.out_path)
                print("---------------------------------- Done! ----------------------------------")

# %%
pdf_path_default = ""       # pdf路径
txt_path_default = ""       # 包含pdf目录信息的txt
offset_default = 0          # 目录页数偏移量
out_path_default = None     # 输出路径
levelmark_default = '.'     # 用于判断书签级别的标志符

pdg = PdfDirGenerator(
    pdf_path = "/Users/qingchuanhou/Documents/GitHub/StudyNote/Small_Project/Content/PDF/1.pdf",
    txt_path = "/Users/qingchuanhou/Documents/GitHub/StudyNote/Small_Project/Content/PDF/1.txt",
    offset = 12, # 一般是目录结束页的页数
    out_path = None,
    levelmark = '.',
)

pdg.run()
# Out:
# --------------------------- Adding the bookmark ---------------------------
#  * PDF Source: /Users/qingchuanhou/Documents/GitHub/StudyNote/Small_Project/Content/PDF/1.pdf
#  * TXT Source: /Users/qingchuanhou/Documents/GitHub/StudyNote/Small_Project/Content/PDF/1.txt
#  * Offset: 12
# ---------------------------------------------------------------------------
#  * [1/111 finished] level: 月录(1), title: , page: 8
#  * [2/111 finished] level: 第1章(1), title: 绪论, page: 13
#  * [3/111 finished] level: 1.1(2), title: 现代疏浚自动监控技术的概念, page: 13
#  * [4/111 finished] level: 1.2(2), title: 现代疏浚自动监控技术的基础, page: 13
#  * [5/111 finished] level: 1.3(2), title: 琉浚自动监控系统原理与组成概述, page: 18
#  * [6/111 finished] level: 第2章(1), title: IHDCS技术, page: 26
#  * [7/111 finished] level: 2.1(2), title: IHDCS 技术特点, page: 26
#  * [8/111 finished] level: 2.2(2), title: IHDCS 的组点, page: 27
#  * [9/111 finished] level: 2.3(2), title: 人机界面（MMI 或 HMI）, page: 28
#  * [10/111 finished] level: 2.4(2), title: IHDCS 的网络结构, page: 30
#  * [11/111 finished] level: 2.5(2), title: IHDCS 监控与数据采集（SCADA）, page: 32
#  * [12/111 finished] level: 2.6(2), title: IHDCS 中的新技术应用, page: 33
#  * [13/111 finished] level: 第3章(1), title: 疏浚自动监控系统中常用的传感器, page: 35
#  * [14/111 finished] level: 3.1(2), title: 传感器的基础知识, page: 35
#  * [15/111 finished] level: 3.2(2), title: 疏浚自动监控系统中用的传感器, page: 40
#  * [16/111 finished] level: 第4章(1), title: GPS卫星信号接收机工作原理, page: 84
#  * [17/111 finished] level: 4.1(2), title: GPS 信号接收机分类, page: 84
#  * [18/111 finished] level: 4.2(2), title: GPS 接收机基本的工作原理, page: 86
#  * [19/111 finished] level: 4.3(2), title: GPS 接收机的基本工作原理, page: 90
#  * [20/111 finished] level: 4.4(2), title: GPS 定位的基本原理, page: 92
#  * [21/111 finished] level: 4.5(2), title: 差分GPS定位系理, page: 95
#  * [22/111 finished] level: 第5章(1), title: 可编程序控侧器, page: 98
#  * [23/111 finished] level: 5.1(2), title: 概述, page: 98
#  * [24/111 finished] level: 5.2(2), title: PLC-S 系列可编程序控制器, page: 101
#  * [25/111 finished] level: 5.3(2), title: LogixSS50 控製器和 ControlLogix 系统, page: 109
#  * [26/111 finished] level: 第6章(1), title: 现场总线 （Fieldbus）技术, page: 112
#  * [27/111 finished] level: 6.1(2), title: 现场总线的基本概念, page: 112
#  * [28/111 finished] level: 6.2(2), title: 现场总线控制系统（FCS）, page: 114
#  * [29/111 finished] level: 6.3(2), title: 瑰用的现场总线简介, page: 115
#  * [30/111 finished] level: 第7章(1), title: 集散控制系统（DCS）, page: 130
#  * [31/111 finished] level: 7.1(2), title: 集散控制系統的基本概念, page: 130
#  * [32/111 finished] level: 7.2(2), title: 集散控製系统网络的组成及其功能, page: 132
#  * [33/111 finished] level: 第8章(1), title: 组态软件技术和监控与數据采集, page: 138
#  * [34/111 finished] level: 8.1(2), title: 组态软件技术, page: 138
#  * [35/111 finished] level: 8.2(2), title: 组态操作, page: 141
#  * [36/111 finished] level: 8.3(2), title: 基于PLC的监督控制与数据采集系统, page: 147
#  * [37/111 finished] level: 8.4(2), title: IHDCS监控与数据采集 (SCADA) 系统, page: 149
#  * [38/111 finished] level: 第9章(1), title: 实时数据库技术及其软件, page: 161
#  * [39/111 finished] level: 9.1(2), title: 实时数据库技术, page: 161
#  * [40/111 finished] level: 9.2(2), title: 实时数据库的基本结构, page: 163
#  * [41/111 finished] level: 9.3(2), title: 实时数据库与关系数据库, page: 165
#  * [42/111 finished] level: 9.4(2), title: 实时数据库在疏浚自动监控中的应用, page: 166
#  * [43/111 finished] level: 9.5(2), title: 实时数据库组态中的现代软件技术, page: 168
#  * [44/111 finished] level: 第10章(1), title: 模糊控制筒介, page: 171
#  * [45/111 finished] level: 10.1(2), title: 概述, page: 171
#  * [46/111 finished] level: 10.2(2), title: 模糊控制的基本原理, page: 173
#  * [47/111 finished] level: 10.3(2), title: 模糊控制器 (模糊控制系统)简介, page: 177
#  * [48/111 finished] level: 第11章(1), title: 自动泥泵控制器 (APC), page: 182
#  * [49/111 finished] level: 11.1(2), title: 自动泥泵控制器工作原理与构成, page: 182
#  * [50/111 finished] level: 11.2(2), title: 自动泥泵控制器的控制, page: 183
#  * [51/111 finished] level: 第12章(1), title: 低浓度泥浆自动排出（ALMO）, page: 188
#  * [52/111 finished] level: 12.1(2), title: 低浓度泥浆自动排出工作原理及操作, page: 188
#  * [53/111 finished] level: 12.2(2), title: 低浓度泥浆自动排出操作, page: 189
#  * [54/111 finished] level: 第13章(1), title: 吃水和装载监视仪（DLM）, page: 192
#  * [55/111 finished] level: 13.1(2), title: 吃水和装载监视仪组成和工作原理, page: 192
#  * [56/111 finished] level: 13.2(2), title: 装载曲线与 DLM 信息显示, page: 195
#  * [57/111 finished] level: 第14章(1), title: 耙吸管位置监视器（STPM）, page: 198
#  * [58/111 finished] level: 14.1(2), title: 粑吸管位置监视器构成及工作原理, page: 198
#  * [59/111 finished] level: 14.2(2), title: STPM 的算法, page: 204
#  * [60/111 finished] level: 14.3(2), title: 操作, page: 206
#  * [61/111 finished] level: 第15章(1), title: 輕吸管紋车控制器（SPWC）, page: 208
#  * [62/111 finished] level: 15.1(2), title: 粑吸管绞车控制器结构, page: 208
#  * [63/111 finished] level: 15.2(2), title: 粑头自动控制器, page: 212
#  * [64/111 finished] level: 第16章(1), title: 产量计, page: 224
#  * [65/111 finished] level: 16.1(2), title: 电磁流量计, page: 224
#  * [66/111 finished] level: 16.2(2), title: 浓度计（y射线浓度计）, page: 227
#  * [67/111 finished] level: 16.3(2), title: 系吸土方（产）量计, page: 233
#  * [68/111 finished] level: 第17章(1), title: 动态定位和动态现踪系统（DP/DT）, page: 236
#  * [69/111 finished] level: 17.1(2), title: 动态定位和动态现踪系统 (DP/DT) 的功能与构成, page: 236
#  * [70/111 finished] level: 17.2(2), title: DP/DT 系统控制面板, page: 240
#  * [71/111 finished] level: 17.3(2), title: 功能页而解幕显示, page: 244
#  * [72/111 finished] level: 17.4(2), title: DP/DT 系统控制模式, page: 252
#  * [73/111 finished] level: 17.5(2), title: DP/DT 系统在 ECDIS 上的应用, page: 257
#  * [74/111 finished] level: 17.6(2), title: DP/DT 系统的操作与控制, page: 258
#  * [75/111 finished] level: 第18章(1), title: 硫没轨渣显示系统（DTPS）, page: 260
#  * [76/111 finished] level: 18.1(2), title: 琥後轨迹显示系统 (DTPS) 功能与构成., page: 260
#  * [77/111 finished] level: 18.2(2), title: DTPS 的组成, page: 261
#  * [78/111 finished] level: 18.3(2), title: 硫浚轨迹显示系统 (DTPS) 菜单页, page: 265
#  * [79/111 finished] level: 18.4(2), title: 在线 (ONLINE) 和离线 (OFFLINE) 应用程序简介, page: 282
#  * [80/111 finished] level: 18.5(2), title: 离线 (OFFLINE), page: 286
#  * [81/111 finished] level: 第19章(1), title: 电子海国是示与信息系统 (ECDIS), page: 297
#  * [82/111 finished] level: 19.1(2), title: 电子海图显示与信息系统 (ECDIS)概述, page: 297
#  * [83/111 finished] level: 19.2(2), title: 电子海图显示与信息系统 (ECDIS), page: 299
#  * [84/111 finished] level: 19.3(2), title: ECDIS 的功能与特点, page: 302
#  * [85/111 finished] level: 19.4(2), title: ECDIS的软件, page: 305
#  * [86/111 finished] level: 19.4(2), title: ECDIS 的信息保证, page: 312
#  * [87/111 finished] level: 19.5(2), title: ECDIS 的数学保证, page: 322
#  * [88/111 finished] level: 第20章(1), title: 耙吸挖泥船计算机辅助硫波决策系统, page: 327
#  * [89/111 finished] level: 20.1(2), title: 概述, page: 327
#  * [90/111 finished] level: 20.2(2), title: 系统框架, page: 329
#  * [91/111 finished] level: 20.4(2), title: 计算机网络系统, page: 336
#  * [92/111 finished] level: 20.5(2), title: 疏浚决策系统的基本模型及原理, page: 339
#  * [93/111 finished] level: 20.6(2), title: 耙吸挖泥船计算机辅助疏浚决策系统的数学方法, page: 348
#  * [94/111 finished] level: 20.8(2), title: 耙吸管绞车自动控制系統, page: 356
#  * [95/111 finished] level: 20.9(2), title: 系統网络结构, page: 360
#  * [96/111 finished] level: 20.10(2), title: 系統实现, page: 361
#  * [97/111 finished] level: 20.11(2), title: “航浚1003” 轮数据无线传愉系统, page: 368
#  * [98/111 finished] level: 20.12(2), title: “航浚1003” 轮数据无线传输系统原理, page: 370
#  * [99/111 finished] level: 20.13(2), title: 中交上航局航道建设有限公司传输网站的建设, page: 376
#  * [100/111 finished] level: 第21章(1), title: 绞吸挖泥船计算机辅助疏浚决筑系统, page: 378
#  * [101/111 finished] level: 21.1(2), title: 绞吸挖泥船计算机辅助疏浚决策系统概述, page: 378
#  * [102/111 finished] level: 21.2(2), title: 系统配置, page: 382
#  * [103/111 finished] level: 21.3(2), title: 绞吸挖泥船辅助决策系统的工作原理, page: 384
#  * [104/111 finished] level: 21.4(2), title: 系统应用软件, page: 386
#  * [105/111 finished] level: 21.5(2), title: 决策系统的模型及数学方法, page: 389
#  * [106/111 finished] level: 21.6(2), title: 合理工况区域模型, page: 396
#  * [107/111 finished] level: 21.7(2), title: 综合曲线分析方法, page: 398
#  * [108/111 finished] level: 21.8(2), title: 绞吸挖泥船辅助决策系统检测技术, page: 403
#  * [109/111 finished] level: 21.9(2), title: 子系统的功能概况, page: 406
#  * [110/111 finished] level: 缩略语(1), title: , page: 411
#  * [111/111 finished] level: 參考文献(1), title: , page: 412
# ---------------------------------------------------------------------------
#  * Save: /Users/qingchuanhou/Documents/GitHub/StudyNote/Small_Project/Content/PDF/1(书签).pdf
# ---------------------------------- Done! ----------------------------------
